# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, LineString
import folium
from folium import GeoJson

# %%
bus_routes = pd.read_csv("../data/bus_routes_full.csv")
bus_stops = pd.read_csv("../data/bus_stops_full.csv")

# %%
bus_routes.head()
# Out:
#   ServiceNo Operator  Direction  StopSequence  BusStopCode  Distance  \
# 0        10     SBST          1             1        75009       0.0
# 1        10     SBST          1             2        76059       0.6
# 2        10     SBST          1             3        76069       1.1
# 3        10     SBST          1             4        96289       2.3
# 4        10     SBST          1             5        96109       2.7
#
#   WD_FirstBus WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus SUN_LastBus
# 0        0500       2300         0500        2300         0500        2300
# 1        0502       2302         0502        2302         0502        2302
# 2        0504       2304         0504        2304         0503        2304
# 3        0508       2308         0508        2309         0507        2308
# 4        0509       2310         0509        2311         0508        2309

# %%
bus_stops.head()
# Out:
#    BusStopCode       RoadName          Description  Latitude   Longitude
# 0         1012    Victoria St  Hotel Grand Pacific  1.296848  103.852536
# 1         1013    Victoria St      St. Joseph's Ch  1.297710  103.853225
# 2         1019    Victoria St      Bras Basah Cplx  1.296990  103.853022
# 3         1029  Nth Bridge Rd         Opp Natl Lib  1.296673  103.854414
# 4         1039  Nth Bridge Rd           Bugis Cube  1.298208  103.855491

# %%
bus_routes_combined = pd.merge(bus_routes, bus_stops, on='BusStopCode', how='left')
bus_routes_combined.head()
# Out:
#   ServiceNo Operator  Direction  StopSequence  BusStopCode  Distance  \
# 0        10     SBST          1             1        75009       0.0
# 1        10     SBST          1             2        76059       0.6
# 2        10     SBST          1             3        76069       1.1
# 3        10     SBST          1             4        96289       2.3
# 4        10     SBST          1             5        96109       2.7
#
#   WD_FirstBus WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus SUN_LastBus  \
# 0        0500       2300         0500        2300         0500        2300
# 1        0502       2302         0502        2302         0502        2302
# 2        0504       2304         0504        2304         0503        2304
# 3        0508       2308         0508        2309         0507        2308
# 4        0509       2310         0509        2311         0508        2309
#
#           RoadName           Description  Latitude   Longitude
# 0  Tampines Ctrl 1          Tampines Int  1.354076  103.943391
# 1   Tampines Ave 5  Opp Our Tampines Hub  1.352962  103.941652
# 2   Tampines Ave 5               Blk 147  1.348753  103.942086
# 3        Simei Ave   Changi General Hosp  1.340055  103.948381
# 4        Simei Ave          Opp Blk 3012  1.337371  103.950673

# %%
bus_routes_combined['geometry'] = bus_routes_combined.apply(lambda x: Point((x.Longitude, x.Latitude)), axis=1)

# %%
bus_routes_combined = gpd.GeoDataFrame(bus_routes_combined, geometry='geometry')

# %%
bus_routes_combined.head()
# Out:
#   ServiceNo Operator  Direction  StopSequence  BusStopCode  Distance  \
# 0        10     SBST          1             1        75009       0.0
# 1        10     SBST          1             2        76059       0.6
# 2        10     SBST          1             3        76069       1.1
# 3        10     SBST          1             4        96289       2.3
# 4        10     SBST          1             5        96109       2.7
#
#   WD_FirstBus WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus SUN_LastBus  \
# 0        0500       2300         0500        2300         0500        2300
# 1        0502       2302         0502        2302         0502        2302
# 2        0504       2304         0504        2304         0503        2304
# 3        0508       2308         0508        2309         0507        2308
# 4        0509       2310         0509        2311         0508        2309
#
#           RoadName           Description  Latitude   Longitude  \
# 0  Tampines Ctrl 1          Tampines Int  1.354076  103.943391
# 1   Tampines Ave 5  Opp Our Tampines Hub  1.352962  103.941652
# 2   Tampines Ave 5               Blk 147  1.348753  103.942086
# 3        Simei Ave   Changi General Hosp  1.340055  103.948381
# 4        Simei Ave          Opp Blk 3012  1.337371  103.950673
#
#                     geometry
# 0  POINT (103.94339 1.35408)
# 1  POINT (103.94165 1.35296)
# 2  POINT (103.94209 1.34875)
# 3  POINT (103.94838 1.34005)
# 4  POINT (103.95067 1.33737)

# %%
bus_routes_combined.to_csv("../data/bus_routes_combined.csv", index=False)

# %%
routes = (
    bus_routes_combined.sort_values(by=['ServiceNo', 'Direction', 'StopSequence'])  # Ensure stops are in the correct order
    .groupby(['ServiceNo', 'Direction'])['geometry']
    .apply(lambda x: LineString(x.tolist()))  # Create LineString from points
    .reset_index()
)

bus_routes_ls = gpd.GeoDataFrame(routes, geometry='geometry', crs="EPSG:4326")

# %%
routes.head()
# Out:
#   ServiceNo  Direction                                           geometry
# 0        10          1  LINESTRING (103.94339 1.35408, 103.94165 1.352...
# 1        10          2  LINESTRING (103.76988 1.29425, 103.76908 1.292...
# 2       100          1  LINESTRING (103.87169 1.35047, 103.87205 1.346...
# 3       100          2  LINESTRING (103.78932 1.31107, 103.78969 1.309...
# 4      100A          1  LINESTRING (103.87169 1.35047, 103.87205 1.346...

# %%
bus_routes_ls.head()
# Out:
#   ServiceNo  Direction                                           geometry
# 0        10          1  LINESTRING (103.94339 1.35408, 103.94165 1.352...
# 1        10          2  LINESTRING (103.76988 1.29425, 103.76908 1.292...
# 2       100          1  LINESTRING (103.87169 1.35047, 103.87205 1.346...
# 3       100          2  LINESTRING (103.78932 1.31107, 103.78969 1.309...
# 4      100A          1  LINESTRING (103.87169 1.35047, 103.87205 1.346...

# %%
mrt_stations = pd.read_csv("../data/MRT Stations.csv")

# %%
mrt_stations.head()
# Out:
#    Unnamed: 0  OBJECTID                    STN_NAME STN_NO  \
# 0           0         1           EUNOS MRT STATION    EW7
# 1           1         2  CHINESE GARDEN MRT STATION   EW25
# 2           2         3          KHATIB MRT STATION   NS14
# 3           3         4          KRANJI MRT STATION    NS7
# 4           4         5         REDHILL MRT STATION   EW18
#
#                                       geometry  Latitude   Longitude
# 0  POINT (103.9032524667383 1.319778951553637)  1.319779  103.903252
# 1  POINT (103.7325967380734 1.342352820874744)  1.342353  103.732597
# 2  POINT (103.8329799077383 1.417383370153547)  1.417383  103.832980
# 3  POINT (103.7621654109002 1.425177698770448)  1.425178  103.762165
# 4   POINT (103.816816670149 1.289562726402453)  1.289563  103.816817

# %%
DT_stations = mrt_stations[mrt_stations['STN_NO'].str.contains(r'\bDT', regex=True)]

# %%
DT_stations.head()
# Out:
#     Unnamed: 0  OBJECTID                   STN_NAME     STN_NO  \
# 10          10        11       TAMPINES MRT STATION   EW2/DT32
# 17          17        18           EXPO MRT STATION   CG1/DT35
# 83          83        94     MACPHERSON MRT STATION  CC10/DT26
# 85          85        96  TAMPINES EAST MRT STATION       DT33
# 86          86        97  TAMPINES WEST MRT STATION       DT31
#
#                                        geometry  Latitude   Longitude
# 10   POINT (103.945148688649 1.353301356342435)  1.353301  103.945149
# 17  POINT (103.9615482107079 1.334549777837812)  1.334550  103.961548
# 83  POINT (103.8902870313661 1.326345371661258)  1.326345  103.890287
# 85  POINT (103.9546344629294 1.356191483037002)  1.356191  103.954634
# 86   POINT (103.9384369713533 1.34551530530169)  1.345515  103.938437

# %%
DT_stations = DT_stations.assign(DT_Code=DT_stations['STN_NO'].str.extract(r'(DT\d+)')) 
DT_stations.head()
# Out:
#     Unnamed: 0  OBJECTID                   STN_NAME     STN_NO  \
# 10          10        11       TAMPINES MRT STATION   EW2/DT32
# 17          17        18           EXPO MRT STATION   CG1/DT35
# 83          83        94     MACPHERSON MRT STATION  CC10/DT26
# 85          85        96  TAMPINES EAST MRT STATION       DT33
# 86          86        97  TAMPINES WEST MRT STATION       DT31
#
#                                        geometry  Latitude   Longitude DT_Code
# 10   POINT (103.945148688649 1.353301356342435)  1.353301  103.945149    DT32
# 17  POINT (103.9615482107079 1.334549777837812)  1.334550  103.961548    DT35
# 83  POINT (103.8902870313661 1.326345371661258)  1.326345  103.890287    DT26
# 85  POINT (103.9546344629294 1.356191483037002)  1.356191  103.954634    DT33
# 86   POINT (103.9384369713533 1.34551530530169)  1.345515  103.938437    DT31

# %%
DT_stations = DT_stations.assign(DT_Number = DT_stations['DT_Code'].str.extract(r'(\d+)').astype(int))
DT_sorted = DT_stations.sort_values(by='DT_Number').reset_index(drop=True)
DT_sorted = DT_sorted.drop(columns=['DT_Code','DT_Number'])
DT_sorted.head()
# Out:
#    Unnamed: 0  OBJECTID                   STN_NAME STN_NO  \
# 0         143       171  BUKIT PANJANG MRT STATION    DT1
# 1         144       172         CASHEW MRT STATION    DT2
# 2         116       136       HILLVIEW MRT STATION    DT3
# 3         165       199           HUME MRT STATION    DT4
# 4         120       140   BEAUTY WORLD MRT STATION    DT5
#
#                                       geometry  Latitude   Longitude
# 0  POINT (103.7615351147329 1.379002116717668)  1.379002  103.761535
# 1  POINT (103.7646944223108 1.369369831064344)  1.369370  103.764694
# 2  POINT (103.7674182544565 1.362344868527861)  1.362345  103.767418
# 3   POINT (103.769099241508 1.354517607525489)  1.354518  103.769099
# 4   POINT (103.7757942852948 1.34122317571135)  1.341223  103.775794

# %%
DT_sorted['geometry'] = DT_sorted.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)
DT_sorted.head()
# Out:
#    Unnamed: 0  OBJECTID                   STN_NAME STN_NO  \
# 0         143       171  BUKIT PANJANG MRT STATION    DT1
# 1         144       172         CASHEW MRT STATION    DT2
# 2         116       136       HILLVIEW MRT STATION    DT3
# 3         165       199           HUME MRT STATION    DT4
# 4         120       140   BEAUTY WORLD MRT STATION    DT5
#
#                                         geometry  Latitude   Longitude
# 0   POINT (103.76153511473294 1.379002116717668)  1.379002  103.761535
# 1  POINT (103.76469442231075 1.3693698310643436)  1.369370  103.764694
# 2  POINT (103.76741825445647 1.3623448685278603)  1.362345  103.767418
# 3  POINT (103.76909924150804 1.3545176075254892)  1.354518  103.769099
# 4    POINT (103.77579428529484 1.34122317571135)  1.341223  103.775794

# %%
DT_sorted = gpd.GeoDataFrame(DT_sorted, geometry='geometry')

route_line = LineString(DT_sorted['geometry'].tolist())
DT_ls = gpd.GeoDataFrame({'Line': ['DTL'], 'geometry': [route_line]}, crs="EPSG:4326") 

DT_ls.head()
# Out:
#   Line                                           geometry
# 0  DTL  LINESTRING (103.76154 1.379, 103.76469 1.36937...

# %%
DT_ls = DT_ls.to_crs(epsg=32648)
bus_routes_ls = bus_routes_ls.to_crs(epsg=32648)

DT_buffer_200= DT_ls.buffer(200).union_all()

# %%
def calculate_overlap(route):
    intersection = route.intersection(DT_buffer_200)
    overlap_length = intersection.length
    route_length = route.length
    overlap_percentage = (overlap_length/route_length)*100 if route_length > 0 else 0
    return pd.Series({'Overlap Length': overlap_length, 'Overlap Percentage': overlap_percentage})

# %%
buffer_overlap_200 = bus_routes_ls.copy()
buffer_overlap_200[['Overlap Length', 'Overlap Percentage']] = buffer_overlap_200['geometry'].apply(calculate_overlap)

# %%
service_overlap = buffer_overlap_200.groupby(['ServiceNo', 'Direction'])[['Overlap Length', 'Overlap Percentage']].sum().reset_index()
print(service_overlap)
# Out:
#     ServiceNo  Direction  Overlap Length  Overlap Percentage
# 0          10          1     1313.061318            4.463913
# 1          10          2     1312.544299            4.465529
# 2         100          1     1214.744649            5.563152
# 3         100          2     1214.398344            5.733302
# 4        100A          1      405.831949            9.254008
# ..        ...        ...             ...                 ...
# 717       992          1        0.000000            0.000000
# 718       992          2        0.000000            0.000000
# 719       993          1        0.000000            0.000000
# 720        9A          1     1327.436287           18.897593
# 721        9B          1     1327.436287           12.731487
#
# [722 rows x 4 columns]

# %%
service_overlap_sorted = service_overlap.sort_values(by='Overlap Percentage', ascending=False)
service_overlap_sorted.head(10)
# Out:
#     ServiceNo  Direction  Overlap Length  Overlap Percentage
# 478        67          2    17698.606243           57.102368
# 252        23          1    14654.502783           52.717147
# 477        67          1    15720.744920           50.884970
# 164       170          1    14330.565692           48.195159
# 165       170          2    13605.444222           45.835109
# 198       184          1     8308.948652           37.996728
# 655      961M          2    11967.176097           34.309908
# 653       961          2    11188.289144           33.692184
# 654      961M          1    11613.438797           33.190888
# 446        65          1     7142.117194           32.908202

# %%
top5_overlap = service_overlap_sorted.head(5)['ServiceNo'].tolist()
top5_bus_routes = routes[routes['ServiceNo'].isin(top5_overlap)]

# %%
top5_bus_routes.head()
# Out:
#     ServiceNo  Direction                                           geometry
# 164       170          1  LINESTRING (103.8565 1.30359, 103.85502 1.3043...
# 165       170          2  LINESTRING (103.74403 1.4939, 103.76827 1.4654...
# 252        23          1  LINESTRING (103.94339 1.35408, 103.94165 1.352...
# 477        67          1  LINESTRING (103.74579 1.38587, 103.743 1.38257...
# 478        67          2  LINESTRING (103.94339 1.35408, 103.94165 1.352...

# %%
sgmap = folium.Map(location=[1.3521, 103.8198], zoom_start=12)

coords = [(lat, lon) for lon,lat in route_line.coords]

folium.PolyLine(
    locations = coords,
    color='blue',
    weight=5,
    opacity=0.8,
    tooltip="Downtown Line"
).add_to(sgmap)

for _,row in DT_sorted.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['STN_NAME'],
        icon=folium.Icon(color='blue', icon='train', prefix='fa')
    ).add_to(sgmap)

# %%
map_buffer = route_line.buffer(0.0018)
gdf_buffer = gpd.GeoDataFrame(geometry=[map_buffer], crs=DT_sorted.crs) 
buffer_geojson = gdf_buffer.to_json()

folium.GeoJson(
    buffer_geojson,
    style_function=lambda x: {
        'fillColor': 'blue',
        'color': 'blue',
        'weight': 1,
        'fillOpacity': 0.5
    },
).add_to(sgmap)

# %%
colors = {
    '67':'red',
    '23':'green',
    '170':'orange'
}

for _, row in top5_bus_routes.iterrows():
    coords = [(lat, lon) for lon,lat in row['geometry'].coords]
    folium.PolyLine(
        locations = coords,
        color=colors.get(row['ServiceNo'], 'black'),
        weight=5,
        opacity=0.8,
        tooltip=f"{row['ServiceNo']} - Direction {row['Direction']}"
    ).add_to(sgmap)

    start_point = coords[0]
    end_point = coords[-1]

    folium.Marker(location=start_point, icon=folium.Icon(color=colors.get(row['ServiceNo'], 'black'))).add_to(sgmap)
    folium.Marker(location=end_point, icon=folium.Icon(color=colors.get(row['ServiceNo'], 'black'))).add_to(sgmap)

# %%
sgmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1bd86b5c77431cc3f68ea0ca9e23983 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1bd86b5c77431cc3f68ea0ca9e23983&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1bd86b5c77431cc3f68ea0ca9e23983 = L.map(
#                 &quot;map_d1bd86b5c77431cc3f68ea0ca9e23983&quot;,
#                 {
#                     center: [1.3521, 103.8198],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ae8d0e2e4730b0d73ad13180fa8c0c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6ae8d0e2e4730b0d73ad13180fa8c0c1.addTo(map_d1bd86b5c77431cc3f68ea0ca9e23983);
#
#
#             var poly_line_631d134f37e32f273abb21622152cc4f = L.polyline(
#                 [[1.379002116717668, 103.76153511473294], [1.3693698310643436, 103.76469442231075], [1.3623448685278603, 103.76741825445647], [1.3545176075254892, 103.76909924150804], [1.34122317571135, 103.77579428529484], [1.3356651207597656, 103.78380665887346], [1.330786387363983, 103.79724631666106], [1.3258832089224446, 103.80732220761212], [1.3221101929847647, 103.81498275034396], [1.3200655570067297, 103.8260244022438], [1.3123200995556394, 103.83798529963272], [1.3068000253123342, 103.8496469665724], [1.3039164839645871, 103.85242168070454], [1.3004650763152503, 103.85570641401658], [1.2932180514893272, 103.860999155887], [1.2818737884915377, 103.8590797651323], [1.279446190378722, 103.85284044403936], [1.2822895361922544, 103.84830280619272], [1.2843595782329786, 103.84342677594374], [1.2924789279174818, 103.84432826960943], [1.2988642704173592, 103.85038425491643], [1.3054036422232524, 103.85547701633922], [1.313672232544496, 103.8629779874744], [1.3215058380176048, 103.8719006257064], [1.3268767147126137, 103.88324750917997], [1.326345371661258, 103.8902870313661], [1.329956825703842, 103.8992525249772], [1.334967301564287, 103.90845973446444], [1.3347421167583993, 103.91797832977343], [1.336607829810492, 103.93223462362464], [1.34551530530169, 103.93843697135333], [1.3533013563424343, 103.945148688649], [1.356191483037002, 103.95463446292943], [1.3417374838931966, 103.9614717886784], [1.3345497778378117, 103.96154821070796]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_d1bd86b5c77431cc3f68ea0ca9e23983);
#
#
#             poly_line_631d134f37e32f273abb21622152cc4f.bindTooltip(
#                 `&lt;div&gt;
#                      Downtown Line
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ca35fac8f2a03e80172f354977110b13 = L.marker(
#                 [1.379002116717668, 103.76153511473294],
#                 {}
#             ).addTo(map_d1bd86b5c77431cc3f68ea0ca9e23983);
#
#
#             var icon_ae66a7e278ebff974fc220c54e8692dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;train&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ca35fac8f2a03e80172f354977110b13.setIcon(icon_ae66a7e278ebff974fc220c54e8692dc);
#
#
#         var popup_2f713ef449e73accf97ac38443d18086 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_289dfd957e203e3795e847f6b7d0e367 = $(`&lt;div id=&quot;html_289dfd957e203e3795e847f6b7d0e367&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BUKIT PANJANG MRT STATION&lt;/div&gt;`)[0];
#                 popup_2f713ef449e73accf97ac38443d18086.setContent(html_289dfd957e203e3795e847f6b7d0e367);
#
#
#
#         marker_ca35fac8f2a03e80172f354977110b13.bindPopup(popup_2f713ef449e73accf97ac38443d18086)
#         ;
#
#
#
#
#             var marker_dfc22feedfc55fe1fb28cf7cd12efbef = L.marker(
#                 [1.3693698310643436, 103.76469442231075],
#                 {}
#             ).addTo(map_d1bd86b5c77431cc3f68ea0ca9e23983);
#
#
#             var icon_17e0c2e207a40b5e9389a0d49057c749 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;train&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
